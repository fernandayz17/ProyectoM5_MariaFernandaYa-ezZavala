# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
# Este notebook realiza el análisis exploratorio del dataset cargado.

# %% [markdown]
# ## 1. Descripción general de los datos
# - Caracterización de los datos: categóricos, numéricos, ordinales, nominales, dicotómicos, politómicos.
# - Revisión de nulos y unificación de su representación.

# %% [markdown]
# ## 2. Unificación de valores nulos y limpieza de datos
# - Unificar la forma de los nulos (por ejemplo, reemplazar 'NA', 'n/a', '', etc. por np.nan).
# - Eliminar variables irrelevantes si es necesario.

# %% [markdown]
# ## 3. Carga y exploración inicial del archivo Excel
# En esta sección se carga el archivo `Base_de_datos.xlsx` y se visualizan las primeras filas para entender la estructura de los datos.

# %%
import pandas as pd
# Cargar el archivo Excel
df = pd.read_excel('../data/Base_de_datos.xlsx')
df.head()
# Out:
#    tipo_credito      fecha_prestamo  capital_prestado  plazo_meses  \
# 0             7 2024-12-21 11:31:35         3692160.0           10
# 1             4 2025-04-22 09:47:35          840000.0            6
# 2             9 2026-01-08 12:22:40         5974028.4           10
# 3             4 2025-08-04 12:04:10         1671240.0            6
# 4             9 2025-04-26 11:24:26         2781636.0           11
#
#    edad_cliente   tipo_laboral  salario_cliente  total_otros_prestamos  \
# 0            42  Independiente          8000000                2500000
# 1            60       Empleado          3000000                2000000
# 2            36  Independiente          4036000                 829000
# 3            48       Empleado          1524547                 498000
# 4            44       Empleado          5000000                4000000
#
#    cuota_pactada    puntaje  ...  saldo_mora  saldo_total  saldo_principal  \
# ...

# %% [markdown]
# ## 4. Información general y estadística descriptiva
# Se revisa la información general del DataFrame y se obtiene una descripción estadística de todas las variables.

# %%
# Información general y estadística descriptiva
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10763 entries, 0 to 10762
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tipo_credito                   10763 non-null  int64
#  1   fecha_prestamo                 10763 non-null  datetime64[ns]
#  2   capital_prestado               10763 non-null  float64
#  3   plazo_meses                    10763 non-null  int64
#  4   edad_cliente                   10763 non-null  int64
#  5   tipo_laboral                   10763 non-null  object
#  6   salario_cliente                10763 non-null  int64
#  7   total_otros_prestamos          10763 non-null  int64
#  8   cuota_pactada                  10763 non-null  int64
#  9   puntaje                        10763 non-null  float64
#  10  puntaje_datacredito            10757 non-null  float64
#  11  cant_creditosvigentes          10763 non-null  int64
# ...

# %% [markdown]
# ## 5. Revisión y tratamiento de valores nulos
# Se identifican y unifican los valores nulos, y se analiza su impacto en las variables.

# %%
# Identificar y unificar valores nulos
df.replace(['NA', 'N/A', '', 'null', 'None'], pd.NA, inplace=True)
df.isnull().sum()
# Out:
# tipo_credito                        0
# fecha_prestamo                      0
# capital_prestado                    0
# plazo_meses                         0
# edad_cliente                        0
# tipo_laboral                        0
# salario_cliente                     0
# total_otros_prestamos               0
# cuota_pactada                       0
# puntaje                             0
# puntaje_datacredito                 6
# cant_creditosvigentes               0
# huella_consulta                     0
# saldo_mora                        156
# saldo_total                       156
# saldo_principal                   405
# saldo_mora_codeudor               590
# creditos_sectorFinanciero           0
# creditos_sectorCooperativo          0
# creditos_sectorReal                 0
# promedio_ingresos_datacredito    2930
# tendencia_ingresos               2932
# Pago_atiempo                        0
# dtype: int64

# %% [markdown]
# ## 6. Análisis de variables categóricas y numéricas
# Se exploran las variables categóricas y numéricas para entender su distribución y valores únicos.

# %%
# Variables categóricas
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    print(f'Columna: {col}')
    print(df[col].value_counts())
    print('-'*30)

# Variables numéricas
num_cols = df.select_dtypes(include='number').columns
df[num_cols].describe()
# Out:
# Columna: tipo_laboral
# tipo_laboral
# Empleado         6754
# Independiente    4009
# Name: count, dtype: int64
# ------------------------------
# Columna: tendencia_ingresos
# tendencia_ingresos
# Creciente      5294
# Decreciente    1291
# Estable        1188
# 0                 7
# 8315              6
# 1000000           4
# 9147              2
# 158042            1
# 168750            1
# 3978              1
# -28589            1
# -566272           1
# 24702             1
# 31837             1
# 122727            1
# 417087            1
# 9090              1
# 173031            1
# -70715            1
# -435177           1
# -702927           1
# -4105             1
# 54683             1
# 22832             1
# 209090            1
# 5697              1
# 10808             1
# -288              1
# -164315           1
# 2029000           1
# 17181             1
# 15245             1
# 82657             1
# 52862             1
# 1817052           1
# 75761             1
# ...

# %% [markdown]
# ## 7. Visualización de variables numéricas y detección de outliers
# Se grafican histogramas y boxplots para analizar la distribución y detectar posibles valores atípicos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogramas de variables numéricas
df[num_cols].hist(figsize=(12,8))
plt.show()

# Boxplots para detectar outliers
for col in num_cols:
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot de {col}')
    plt.show()

# %% [markdown]
# ## 8. Análisis de correlación entre variables numéricas
# Se analiza la correlación entre variables numéricas para identificar relaciones importantes.

# %%
# Gráfico de correlación más legible
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', cbar=True, square=True, annot_kws={"size":8})
plt.title('Matriz de correlación', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Comentarios y conclusiones
# En esta sección, describe tus hallazgos principales, variables relevantes, problemas detectados y posibles transformaciones a realizar en los datos.

# %% [markdown]
# ## Comentarios y conclusiones del EDA
#
# - **Calidad de los datos:** Se identificaron algunos valores nulos en variables como salario_cliente y puntaje_datacredito, los cuales fueron unificados y podrán ser imputados o eliminados según su relevancia. No se detectaron inconsistencias graves, aunque existen algunas variables con baja variabilidad.
#
# - **Variables relevantes:** Destacan capital_prestado, plazo_meses, edad_cliente y puntaje_datacredito por su correlación con el objetivo y su variabilidad. Variables como tipo_credito y Pago_atiempo también muestran potencial relevancia para el modelado.
#
# - **Relaciones encontradas:** Se observan correlaciones positivas entre capital_prestado y saldo_total, así como entre puntaje_datacredito y Pago_atiempo. Algunas variables presentan correlaciones bajas o nulas, lo que sugiere independencia o poca relación con el objetivo.
#
# - **Transformaciones necesarias:** Será útil escalar variables numéricas y convertir variables categóricas a formato numérico. Se recomienda crear variables derivadas como ratio entre capital_prestado y salario_cliente, y analizar posibles outliers en variables financieras.
#
# - **Siguientes pasos:** Imputar o eliminar nulos, realizar ingeniería de variables, y profundizar en el análisis de las variables más correlacionadas con el objetivo. También se sugiere explorar interacciones entre variables y preparar los datos para el modelado predictivo.
