# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
# Este notebook realiza el análisis exploratorio del dataset cargado.

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset
ruta = '../data/ejemplo.csv'
df = pd.read_csv(ruta)
df.head()

# %% [markdown]
# ## 1. Descripción general de los datos
# - Caracterización de los datos: categóricos, numéricos, ordinales, nominales, dicotómicos, politómicos.
# - Revisión de nulos y unificación de su representación.

# %%
# Tipos de datos y revisión de nulos
df.info()
print("\nValores nulos por columna:")
print(df.isnull().sum())

# %% [markdown]
# ## 2. Unificación de valores nulos y limpieza de datos
# - Unificar la forma de los nulos (por ejemplo, reemplazar 'NA', 'n/a', '', etc. por np.nan).
# - Eliminar variables irrelevantes si es necesario.

# %%
import numpy as np
# Unificar valores nulos comunes a np.nan
df.replace(['NA', 'N/A', 'n/a', '', 'null', 'None'], np.nan, inplace=True)

# Eliminar columnas irrelevantes si es necesario (ejemplo)
# df.drop(['columna_irrelevante'], axis=1, inplace=True)
df.head()
