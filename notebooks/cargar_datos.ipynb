# %% [markdown]
# # Cargar Datos
# Este notebook carga un dataset de ejemplo en formato CSV para su posterior análisis.

# %%
# Importar librerías necesarias
import pandas as pd

# Cargar el dataset de ejemplo (ajusta el nombre si tienes un archivo específico)
df = pd.read_csv('../data/ejemplo.csv')
df.head()
